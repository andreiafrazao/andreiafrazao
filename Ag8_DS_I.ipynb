# %% [markdown]
# <a href="https://colab.research.google.com/github/andreiafrazao/andreiafrazao/blob/main/Ag8_DS_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
totalExcelente = 0
totalBom = 0
totalRuim = 0


for item in range (50):
  nomeCliente = input("Digite seu nome:")
  idadeCliente = input("Digite sua idade:")
  opiniaoAtendimento = int(input("Opinião 1-EXCELENTE, 2-BOM, 3-RUIM: "))

  if opiniaoAtendimento == 1:
    totalExcelente = totalExcelente + 1
  elif opiniaoAtendimento == 3:
    totalRuim = totalRuim + 1
  elif opiniaoAtendimento == 2:
    totalBom = totalBom + 1
  else:
    print("Opinião inválida! Digite um número de 1 a 3.")

print("Resultados da pesquisa:")
print(f"Quantidade de respostas EXCELENTE: {totalExcelente}")
print(f"Quantidade de respostas RUIM: {totalRuim}")
# Out:
# Digite seu nome:Ana
# Digite sua idade:22
# Opinião 1-EXCELENTE, 2-BOM, 3-RUIM: 1
# Digite seu nome:João
# Digite sua idade:33
# Opinião 1-EXCELENTE, 2-BOM, 3-RUIM: 2
# Digite seu nome:José
# Digite sua idade:49
# Opinião 1-EXCELENTE, 2-BOM, 3-RUIM: 1
# Digite seu nome:Maria
# Digite sua idade:45
# Opinião 1-EXCELENTE, 2-BOM, 3-RUIM: 3
# Digite seu nome:Carolina
# Digite sua idade:30
# Opinião 1-EXCELENTE, 2-BOM, 3-RUIM: 3
# Digite seu nome:Luna
# Digite sua idade:20
# Opinião 1-EXCELENTE, 2-BOM, 3-RUIM: 3
# Digite seu nome:Márcio
# Digite sua idade:50
# Opinião 1-EXCELENTE, 2-BOM, 3-RUIM: 1
# Digite seu nome:Isabela
# Digite sua idade:19
# Opinião 1-EXCELENTE, 2-BOM, 3-RUIM: 3
# Digite seu nome:Jonas
# Digite sua idade:33
# Opinião 1-EXCELENTE, 2-BOM, 3-RUIM: 3
# Digite seu nome:Kira
# Digite sua idade:21
# Opinião 1-EXCELENTE, 2-BOM, 3-RUIM: 2
# Resultados da pesquisa:
# Quantidade de respostas EXCELENTE: 3
# Quantidade de respostas RUIM: 5
